# %%
## author- KUMAR ABHINAV
## DATE- 20/3/19
import pandas as pd
import numpy as np
import os
file_path=os.getcwd()

# %%
print('file_path:'+file_path)
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 25, 10
import matplotlib.pyplot as plt
from matplotlib import pyplot
# Out:
# file_path:C:\Users\Lenovo\AnacondaProjects\hungryaap

# %%
df=pd.read_csv(r"C:\Users\Lenovo\AnacondaProjects\hungryaap\worldcities.csv")

# %%
df.head()
# Out:
#           city   city_ascii      lat      lng country iso2 iso3   admin_name  \
# 0    Malishevë    Malisheve  42.4822  20.7458  Kosovo   XK  XKS    Malishevë
# 1      Prizren      Prizren  42.2139  20.7397  Kosovo   XK  XKS      Prizren
# 2  Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo   XK  XKS  Zubin Potok
# 3     Kamenicë     Kamenice  42.5781  21.5803  Kosovo   XK  XKS     Kamenicë
# 4         Viti         Viti  42.3214  21.3583  Kosovo   XK  XKS         Viti
#
#   capital  population          id
# 0   admin         NaN  1901597212
# 1   admin         NaN  1901360309
# 2   admin         NaN  1901608808
# 3   admin         NaN  1901851592
# 4   admin         NaN  1901328795

# %%
print("df :%s"%(df.shape,))
# Out:
# df :(12893, 11)

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline
plt.scatter(df.lat,df.lng)
plt.xlabel('latitude')
plt.ylabel('longitude')
# Out:
# Text(0,0.5,'longitude')

# %%
km = KMeans(n_clusters=10)
y_predicted = km.fit_predict(df[['lat','lng']])
y_predicted
# Out:
# array([2, 2, 2, ..., 1, 1, 7])

# %%
df['cluster']=y_predicted
df.head()
# Out:
#           city   city_ascii      lat      lng country iso2 iso3   admin_name  \
# 0    Malishevë    Malisheve  42.4822  20.7458  Kosovo   XK  XKS    Malishevë
# 1      Prizren      Prizren  42.2139  20.7397  Kosovo   XK  XKS      Prizren
# 2  Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo   XK  XKS  Zubin Potok
# 3     Kamenicë     Kamenice  42.5781  21.5803  Kosovo   XK  XKS     Kamenicë
# 4         Viti         Viti  42.3214  21.3583  Kosovo   XK  XKS         Viti
#
#   capital  population          id  cluster
# 0   admin         NaN  1901597212        2
# 1   admin         NaN  1901360309        2
# 2   admin         NaN  1901608808        2
# 3   admin         NaN  1901851592        2
# 4   admin         NaN  1901328795        2

# %%
km.cluster_centers_
# Out:
# array([[  43.41314348,  124.35053591],
#        [  36.92774391,  -84.90424698],
#        [  47.21123811,   15.50298397],
#        [ -16.40395033,  -60.21813201],
#        [  14.78727449,  102.39561347],
#        [ -27.24926778,  147.81258997],
#        [  -6.18298238,   30.44469038],
#        [  38.82161563, -117.1290722 ],
#        [  42.15496741,   58.77465703],
#        [  12.24897137,   -1.913825  ]])

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
df4 = df[df.cluster==3]
df5 = df[df.cluster==4]
df6 = df[df.cluster==5]
df7 = df[df.cluster==6]
df8 = df[df.cluster==7]
df9 = df[df.cluster==8]
df10 = df[df.cluster==9]
plt.scatter(df1.lat,df1.lng,color='green')
plt.scatter(df2.lat,df2.lng,color='red')
plt.scatter(df3.lat,df3.lng,color='black')
plt.scatter(df4.lat,df4.lng,color='blue')
plt.scatter(df5.lat,df5.lng,color='violet')
plt.scatter(df6.lat,df6.lng,color='cyan')
plt.scatter(df7.lat,df7.lng,color='indigo')
plt.scatter(df8.lat,df8.lng,color='orange')
plt.scatter(df9.lat,df9.lng,color='yellow')
plt.scatter(df10.lat,df10.lng,color='pink')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.legend()

# %%
scaler = MinMaxScaler()

scaler.fit(df[['lng']])
df['lng'] = scaler.transform(df[['lng']])

scaler.fit(df[['lat']])
df['lat'] = scaler.transform(df[['lat']])

# %%
df.head()
# Out:
#           city   city_ascii       lat       lng country iso2 iso3  \
# 0    Malishevë    Malisheve  0.708906  0.558080  Kosovo   XK  XKS
# 1      Prizren      Prizren  0.706954  0.558063  Kosovo   XK  XKS
# 2  Zubin Potok  Zubin Potok  0.712052  0.557924  Kosovo   XK  XKS
# 3     Kamenicë     Kamenice  0.709604  0.560405  Kosovo   XK  XKS
# 4         Viti         Viti  0.707736  0.559786  Kosovo   XK  XKS
#
#     admin_name capital  population          id  cluster
# 0    Malishevë   admin         NaN  1901597212        2
# 1      Prizren   admin         NaN  1901360309        2
# 2  Zubin Potok   admin         NaN  1901608808        2
# 3     Kamenicë   admin         NaN  1901851592        2
# 4         Viti   admin         NaN  1901328795        2

# %%
plt.scatter(df.lat,df.lng)

# %%
km = KMeans(n_clusters=10)
y_predicted = km.fit_predict(df[['lat','lng']])
y_predicted
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
df['cluster']=y_predicted
df.head()
# Out:
#           city   city_ascii       lat       lng country iso2 iso3  \
# 0    Malishevë    Malisheve  0.708906  0.558080  Kosovo   XK  XKS
# 1      Prizren      Prizren  0.706954  0.558063  Kosovo   XK  XKS
# 2  Zubin Potok  Zubin Potok  0.712052  0.557924  Kosovo   XK  XKS
# 3     Kamenicë     Kamenice  0.709604  0.560405  Kosovo   XK  XKS
# 4         Viti         Viti  0.707736  0.559786  Kosovo   XK  XKS
#
#     admin_name capital  population          id  cluster
# 0    Malishevë   admin         NaN  1901597212        1
# 1      Prizren   admin         NaN  1901360309        1
# 2  Zubin Potok   admin         NaN  1901608808        1
# 3     Kamenicë   admin         NaN  1901851592        1
# 4         Viti   admin         NaN  1901328795        1

# %%
km.cluster_centers_
# Out:
# array([[ 0.68237154,  0.24311165],
#        [ 0.67184432,  0.59036148],
#        [ 0.22289322,  0.33621887],
#        [ 0.44607242,  0.54806958],
#        [ 0.52530444,  0.78034008],
#        [ 0.4670519 ,  0.28244365],
#        [ 0.2126748 ,  0.90095968],
#        [ 0.77847494,  0.55046048],
#        [ 0.73782431,  0.82114268],
#        [ 0.26713647,  0.58043242]])

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
df4 = df[df.cluster==3]
df5 = df[df.cluster==4]
df6 = df[df.cluster==5]
df7 = df[df.cluster==6]
df8 = df[df.cluster==7]
df9 = df[df.cluster==8]
df10 = df[df.cluster==9]
plt.scatter(df1.lat,df1.lng,color='green')
plt.scatter(df2.lat,df2.lng,color='red')
plt.scatter(df3.lat,df3.lng,color='black')
plt.scatter(df4.lat,df4.lng,color='blue')
plt.scatter(df5.lat,df5.lng,color='violet')
plt.scatter(df6.lat,df6.lng,color='cyan')
plt.scatter(df7.lat,df7.lng,color='indigo')
plt.scatter(df8.lat,df8.lng,color='orange')
plt.scatter(df9.lat,df9.lng,color='yellow')
plt.scatter(df10.lat,df10.lng,color='pink')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.legend()

# %% [markdown]
# # Elbow Curve to find optimum value for clusters

# %%
sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df[['lat','lng']])
    sse.append(km.inertia_)

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %% [markdown]
# # so optimum value is k is 3 from above plot of sse vs  k
# ## so we will try k means clustering with no of clusters =3

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(df[['lat','lng']])
y_predicted
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
df['cluster']=y_predicted
df.head()
# Out:
#           city   city_ascii      lat      lng country iso2 iso3   admin_name  \
# 0    Malishevë    Malisheve  42.4822  20.7458  Kosovo   XK  XKS    Malishevë
# 1      Prizren      Prizren  42.2139  20.7397  Kosovo   XK  XKS      Prizren
# 2  Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo   XK  XKS  Zubin Potok
# 3     Kamenicë     Kamenice  42.5781  21.5803  Kosovo   XK  XKS     Kamenicë
# 4         Viti         Viti  42.3214  21.3583  Kosovo   XK  XKS         Viti
#
#   capital  population          id  cluster
# 0   admin         NaN  1901597212        2
# 1   admin         NaN  1901360309        2
# 2   admin         NaN  1901608808        2
# 3   admin         NaN  1901851592        2
# 4   admin         NaN  1901328795        2

# %%
km.cluster_centers_
# Out:
# array([[  28.75995013,  -86.99394252],
#        [  20.53811819,  112.09955439],
#        [  30.71756739,   22.43740365]])

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
plt.scatter(df1.lat,df1.lng,color='green')
plt.scatter(df2.lat,df2.lng,color='red')
plt.scatter(df3.lat,df3.lng,color='black')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.legend()

# %% [markdown]
# # Hierarchical Clustering Algorithm

# %%
data = df.iloc[:, 2:4].values

# %%
data
# Out:
# array([[  42.4822,   20.7458],
#        [  42.2139,   20.7397],
#        [  42.9144,   20.6897],
#        ...,
#        [  43.5928,  -96.5799],
#        [  44.0062,  -97.1084],
#        [  44.6635, -103.8562]])

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))  
plt.title("Location Dendograms")  
dend = shc.dendrogram(shc.linkage(data, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster1 = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')  
cluster1.fit_predict(data)
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(data[:,0], data[:,1], c=cluster1.labels_, cmap='rainbow')

# %%
cluster2 = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')  
cluster2.fit_predict(data)
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(data[:,0], data[:,1], c=cluster2.labels_, cmap='rainbow')

# %%
cluster3 = AgglomerativeClustering(n_clusters=10, affinity='euclidean', linkage='ward')  
cluster3.fit_predict(data)
# Out:
# array([2, 2, 2, ..., 0, 0, 6], dtype=int64)

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(data[:,0], data[:,1], c=cluster3.labels_, cmap='rainbow')

# %% [markdown]
# # K Nearest Neighbour

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors = 15

# we only take the first two features. We could avoid this ugly
# slicing by using a two-dim dataset
X = data
y = df.cluster

h = .02  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
